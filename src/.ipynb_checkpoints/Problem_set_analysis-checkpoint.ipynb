# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
problem_df = pd.read_csv("../data/problemsetall_data.csv")
problem_stat_df = pd.read_csv("../data/problemsetproblem_stat.csv")

# %%
problem_df = problem_df.set_index('contestId')
problem_stat_df = problem_stat_df.set_index('contestId')
problem_df.head()
# Out:
#                    Problem_name         type   rating  \
# contestId
# 1154       Minimum Possible LCM  PROGRAMMING   2400.0
# 1154               Shovels Shop  PROGRAMMING   2300.0
# 1154                  Two Teams  PROGRAMMING   1800.0
# 1154              Walking Robot  PROGRAMMING   1400.0
# 1154                Gourmet Cat  PROGRAMMING   1400.0
#
#                                                         tags  level
# contestId
# 1154       ['brute force'/ 'greedy'/ 'math'/ 'number theo...      G
# 1154                                        ['dp'/ 'greedy']      F
# 1154       ['data structures'/ 'implementation'/ 'sortings']      E
# 1154                                              ['greedy']      D
# 1154                              ['implementation'/ 'math']      C

# %%
problem_df.head()
# Out:
#    contestId          Problem_name         type   rating  \
# 0       1154  Minimum Possible LCM  PROGRAMMING   2400.0
# 1       1154          Shovels Shop  PROGRAMMING   2300.0
# 2       1154             Two Teams  PROGRAMMING   1800.0
# 3       1154         Walking Robot  PROGRAMMING   1400.0
# 4       1154           Gourmet Cat  PROGRAMMING   1400.0
#
#                                                 tags  level
# 0  ['brute force'/ 'greedy'/ 'math'/ 'number theo...      G
# 1                                   ['dp'/ 'greedy']      F
# 2  ['data structures'/ 'implementation'/ 'sortings']      E
# 3                                         ['greedy']      D
# 4                         ['implementation'/ 'math']      C

# %%
tag_str = list(problem_df[problem_df.columns[4]])
tag_str = [i[1:-2].replace(" ", "").split("/") for i in tag_str]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-0a3952d08415> in <module>
#       1 tag_str = list(problem_df[problem_df.columns[4]])
# ----> 2 tag_str = [i[1:-2].split("/").replace(" ", "") for i in tag_str]
#
# <ipython-input-31-0a3952d08415> in <listcomp>(.0)
#       1 tag_str = list(problem_df[problem_df.columns[4]])
# ----> 2 tag_str = [i[1:-2].split("/").replace(" ", "") for i in tag_str]
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
tag_str
# Out:
# [["'brute force'", " 'greedy'", " 'math'", " 'number theory"],
#  ["'dp'", " 'greedy"],
#  ["'data structures'", " 'implementation'", " 'sortings"],
#  ["'greedy"],
#  ["'implementation'", " 'math"],
#  ["'math"],
#  ["'math"],
#  ["'combinatorics'", " 'dp'", " 'math'", " 'probabilities"],
#  ["'binary search'", " 'brute force"],
#  ["'binary search'", " 'dfs and similar'", " 'dp'", " 'greedy'", " 'trees"],
#  ["'greedy'", " 'strings"],
#  ["'constructive algorithms'", " 'greedy"],
#  ["'brute force'", " 'math"],
#  ["'combinatorics'", " 'dp'", " 'matrices'", " 'probabilities"],
#  ["'combinatorics'", " 'dp'", " 'math"],
#  ["'greedy'", " 'math'", " 'sortings"],
#  ["'constructive algorithms'", " 'math"],
#  ["'bitmasks'", " 'brute force'", " 'constructive algorithms'", " 'dp"],
#  ["'brute force'", " 'strings"],
#  ["'dp'", " 'geometry"],
#  ["'dp'", " 'flows'", " 'graphs"],
#  ["'dp'", " 'trees"],
#  ["'data structures'", " 'divide and conquer"],
# ...
